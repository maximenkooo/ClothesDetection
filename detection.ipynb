# %%
# %cd /content/drive/My Drive/keras-yolo3
# Out:
# /content/drive/My Drive/keras-yolo3

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 2.4MB 2.8MB/s
# ...
#      |████████████████████████████████| 2.9MB 17.3MB/s
# ...
#      |████████████████████████████████| 378kB 26.6MB/s
# ...
#      |████████████████████████████████| 92kB 8.5MB/s
# ...
#      |████████████████████████████████| 20.2MB 26.4MB/s
# ...
#      |████████████████████████████████| 1.3MB 32.8MB/s
# ...
#      |████████████████████████████████| 276kB 37.1MB/s
# ...
#      |████████████████████████████████| 61kB 6.9MB/s
# ...
#      |████████████████████████████████| 327kB 31.8MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3-cp36-cp36m-linux_x86_64.whl size=44229 sha256=b0d5088a6cd6f60efe4b6d420d2a2d885686eb89994ae897a6ccc378f47a685f
#   Stored in directory: /root/.cache/pip/wheels/e4/76/4d/a95b8dd7b452b69e8ed4f68b69e1b55e12c9c9624dd962b191
# Successfully built PyYAML
# ERROR: google-colab 1.0.0 has requirement six~=1.12.0, but you'll have six 1.14.0 which is incompatible.
# ...

# %%
# !python yolo3_one_file_to_detect_them_all.py -w yolov3.weights -i test_images/enot2.jpg
# Out:
# Using TensorFlow backend.
# yolov3.weights
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
# !python yolo3_one_file_to_detect_them_all.py -w yolov3.weights -i test_images/dress2.jpg
# Out:
# Using TensorFlow backend.
# yolov3.weights
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# ...

# %%
# !python predict.py -c config.json -i test_images/moda.jpg
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-02-22 11:20:22.699792: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-02-22 11:20:22.726288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-02-22 11:20:22.726899: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P4 major: 6 minor: 1 memoryClockRate(GHz): 1.1135
# pciBusID: 0000:00:04.0
# ...

# %%
from IPython.display import Image
Image('output/enot.jpg')

# %% [markdown]
# **Try to detect more classes**

# %% [markdown]
# path to trian set - /content/drive/My Drive/keras-yolo3/OIDv4_ToolKit/OID/Dataset/train/Shorts_Dress
#
# path to validation set - /content/drive/My Drive/keras-yolo3/OIDv4_ToolKit/OID/Dataset/validation/Shorts_Dress
#
# path to train annot - /content/drive/My Drive/keras-yolo3/OIDv4_ToolKit/OID/csv_folder/train-annotations-bbox.csv
#
# path to valid annot - /content/drive/My Drive/keras-yolo3/OIDv4_ToolKit/OID/csv_folder/validation-annotations-bbox.csv
#
# path to description - /content/drive/My Drive/keras-yolo3/OIDv4_ToolKit/OID/csv_folder/class-descriptions-boxable.csv

# %%
# !cd OIDv4_ToolKit && pip install -r requirements.txt
# Out:
# ...
# Processing /root/.cache/pip/wheels/54/b7/c7/2ada654ee54483c9329871665aaf4a6056c3ce36f29cf66e67/PyYAML-5.2-cp36-cp36m-linux_x86_64.whl
# ...
#   Found existing installation: PyYAML 5.3
#     Uninstalling PyYAML-5.3:
#       Successfully uninstalled PyYAML-5.3
# ...

# %%
! cd OIDv4_ToolKit && python3 convert_xml.py
# Out:
# Currently in Subdirectory: train
#
# Creating PASCAL VOC XML Files for Class: Shorts_Dress_Coat_Suit_Skirt_Jacket_Jeans_Swimwear
# /content/drive/My Drive/keras-yolo3/OIDv4_ToolKit/OID/Dataset/train/Shorts_Dress_Coat_Suit_Skirt_Jacket_Jeans_Swimwear
# 100% 4569/4569 [2:08:31<00:00,  1.69s/it]
# Currently in Subdirectory: validation
#
# Creating PASCAL VOC XML Files for Class: Shorts_Dress_Coat_Suit_Skirt_Jacket_Jeans_Swimwear
# /content/drive/My Drive/keras-yolo3/OIDv4_ToolKit/OID/Dataset/validation/Shorts_Dress_Coat_Suit_Skirt_Jacket_Jeans_Swimwear
# 100% 1071/1071 [29:15<00:00,  1.64s/it]
# Currently in Subdirectory: test
#
# Creating PASCAL VOC XML Files for Class: Shorts_Dress_Coat_Suit_Skirt_Jacket_Jeans_Swimwear
# /content/drive/My Drive/keras-yolo3/OIDv4_ToolKit/OID/Dataset/test/Shorts_Dress_Coat_Suit_Skirt_Jacket_Jeans_Swimwear
# 100% 1834/1834 [52:58<00:00,  1.73s/it]

# %%
# !python gen_anchors.py -c config.json -a 9
# Out:
# Streaming output truncated to the last 5000 lines.
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear']
# ...

# %%
# !python train.py -c config.json
# Out:
# Using TensorFlow backend.
# 2020-02-22 14:24:56.461530: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-02-22 14:24:56.466005: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000175000 Hz
# 2020-02-22 14:24:56.466222: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x173ebc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-02-22 14:24:56.466252: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-02-22 14:24:56.468099: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !python train.py -c config.json
# Out:
# Using TensorFlow backend.
# 2020-02-22 12:54:20.507385: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX512F
# 2020-02-22 12:54:20.511773: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2000175000 Hz
# 2020-02-22 12:54:20.512003: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2992bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-02-22 12:54:20.512034: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-02-22 12:54:20.513696: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# ...

# %%
# !wget https://nekoshop.ru/wa-data/public/shop/products/43/66/16643/images/39287/39287.750@2x.jpg -O test_images/coat3.jpg
# Out:
# --2020-02-26 15:06:18--  https://nekoshop.ru/wa-data/public/shop/products/43/66/16643/images/39287/39287.750@2x.jpg
# Resolving nekoshop.ru (nekoshop.ru)... 37.140.192.198
# Connecting to nekoshop.ru (nekoshop.ru)|37.140.192.198|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36317 (35K) [image/jpeg]
# Saving to: ‘test_images/coat3.jpg’
#
# test_images/coat3.j 100%[===================>]  35.47K  --.-KB/s    in 0.1s
#
# 2020-02-26 15:06:19 (256 KB/s) - ‘test_images/coat3.jpg’ saved [36317/36317]

# %%
# !python predict.py -c config.json -i test_images/clothes2.jpg
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-02-26 15:24:59.000112: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-02-26 15:24:59.001907: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-02-26 15:24:59.001950: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (3b3f314095b5): /proc/driver/nvidia/version does not exist
# ...

# %%
# !python predict.py -c config.json -i test_images/clothes6.jpg
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2020-02-26 15:41:22.249956: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-02-26 15:41:22.251824: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-02-26 15:41:22.251880: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (3b3f314095b5): /proc/driver/nvidia/version does not exist
# ...

# %% [markdown]
# Download dataset

# %%
! cd OIDv4_ToolKit &&  python3 main.py downloader --classes Shorts Dress Coat Suit Skirt Jacket Jeans Swimwear --type_csv train --multiclasses 1 --limit 600
! cd OIDv4_ToolKit &&  python3 main.py downloader --classes Shorts Dress Coat Suit Skirt Jacket Jeans Swimwear --type_csv validation --multiclasses 1 --limit 300
! cd OIDv4_ToolKit &&  python3 main.py downloader --classes Shorts Dress Coat Suit Skirt Jacket Jeans Swimwear --type_csv test --multiclasses 1 --limit 300
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Shorts', 'Dress', 'Coat', 'Suit', 'Skirt', 'Jacket', 'Jeans', 'Swimwear'] together.
#
# Shorts
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 6833 online images for train.
#     [INFO] | Limiting to 600 images.
# ...
